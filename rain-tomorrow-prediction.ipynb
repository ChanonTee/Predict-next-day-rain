# %% [markdown]
# # Load data

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("weatherAUS.csv")
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %% [markdown]
# # Clean data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
df.isnull().any()
# Out:
# Date             False
# Location         False
# MinTemp           True
# MaxTemp           True
# Rainfall          True
# Evaporation       True
# Sunshine          True
# WindGustDir       True
# WindGustSpeed     True
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am      True
# WindSpeed3pm      True
# Humidity9am       True
# Humidity3pm       True
# Pressure9am       True
# Pressure3pm       True
# Cloud9am          True
# Cloud3pm          True
# Temp9am           True
# Temp3pm           True
# RainToday         True
# RainTomorrow      True
# dtype: bool

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
raining = df[df['Rainfall'] > 1 ]

# %%
plt.figure(figsize=(15,10))


plt.subplot(3, 2, 1)
sns.histplot(raining['Rainfall'], bins=30)

plt.subplot(3, 2, 2)
sns.histplot(df['Evaporation'], bins=10)

plt.subplot(3, 2, 3)
sns.histplot(df['WindSpeed9am'], bins=10)

plt.subplot(3, 2, 4)
sns.histplot(df['WindSpeed3pm'], bins=10)

plt.subplot(3, 2, 5)
sns.histplot(df['WindGustSpeed'], bins=10)
# Out:
# <Axes: xlabel='WindGustSpeed', ylabel='Count'>

# %%
def replace_outliers_median(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    df.loc[(df[column] < Q1 - 1.5*IQR) | \
           (df[column] > Q3 + 1.5*IQR), column]\
            = df[column].median()

    return df

# %%
df = replace_outliers_median(df, 'Evaporation')
df = replace_outliers_median(df, 'WindSpeed9am')
df = replace_outliers_median(df, 'WindSpeed3pm')
df = replace_outliers_median(df, 'WindGustSpeed')

# %%
Q1 = raining['Rainfall'].quantile(0.25)
Q3 = raining['Rainfall'].quantile(0.75)
IQR = Q3 - Q1
top = Q3 + 1.5*IQR
bot = Q1 - 1.5*IQR
print(bot,top)

df = df.loc[(df['Rainfall'] > bot) &  (df['Rainfall'] < top)]
# Out:
# -11.700000000000001 25.900000000000002

# %%
df.fillna(df.select_dtypes('number').median(), inplace=True)
# Out:
# C:\Users\66952\AppData\Local\Temp\ipykernel_16016\680116613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.select_dtypes('number').median(), inplace=True)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  139451.000000  139451.000000  139451.000000  139451.000000
# mean       12.105468      23.241160       1.458604       4.965614
# std         6.384056       7.120226       3.762132       2.353844
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.500000      17.900000       0.000000       4.000000
# 50%        11.900000      22.600000       0.000000       4.800000
# 75%        16.700000      28.200000       0.600000       5.200000
# max        33.900000      48.100000      25.800000      14.600000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  139451.000000  139451.000000  139451.000000  139451.000000
# mean        8.131048      38.909137      13.562907      18.158658
# std         2.746524      11.471201       8.154886       7.921518
# min         0.000000       6.000000       0.000000       0.000000
# 25%         8.300000      31.000000       7.000000      13.000000
# 50%         8.600000      39.000000      13.000000      19.000000
# 75%         8.800000      46.000000      19.000000      24.000000
# max        14.500000      72.000000      37.000000      39.000000
#
#          Humidity9am    Humidity3pm    Pressure9am    Pressure3pm  \
# count  139451.000000  139451.000000  139451.000000  139451.000000
# mean       68.500319      51.057361    1017.756121    1015.341841
# std        18.905620      20.371890       6.702101       6.647970
# min         0.000000       0.000000     982.000000     977.100000
# 25%        57.000000      37.000000    1013.600000    1011.100000
# 50%        69.000000      52.000000    1017.700000    1015.300000
# 75%        82.000000      65.000000    1021.900000    1019.500000
# max       100.000000     100.000000    1041.000000    1039.600000
#
#             Cloud9am       Cloud3pm        Temp9am        Temp3pm
# count  139451.000000  139451.000000  139451.000000  139451.000000
# mean        4.613900       4.675922      16.952041      21.694584
# std         2.296032       2.119102       6.491159       6.885241
# min         0.000000       0.000000      -7.200000      -5.400000
# 25%         3.000000       4.000000      12.300000      16.700000
# 50%         5.000000       5.000000      16.700000      21.100000
# 75%         6.000000       6.000000      21.500000      26.300000
# max         9.000000       9.000000      40.200000      46.700000

# %%
df.isnull().any()
# Out:
# Date             False
# Location         False
# MinTemp          False
# MaxTemp          False
# Rainfall         False
# Evaporation      False
# Sunshine         False
# WindGustDir       True
# WindGustSpeed    False
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am     False
# WindSpeed3pm     False
# Humidity9am      False
# Humidity3pm      False
# Pressure9am      False
# Pressure3pm      False
# Cloud9am         False
# Cloud3pm         False
# Temp9am          False
# Temp3pm          False
# RainToday        False
# RainTomorrow      True
# dtype: bool

# %%
plt.figure(figsize = (16,5))

plt.subplot(1, 3, 1)
plt.title('Wind Gust Direction Counts')
sns.countplot(data=df, y='WindGustDir')

plt.subplot(1, 3, 2)
plt.title('Wind 9am Direction Counts')
sns.countplot(data=df, y='WindDir9am')

plt.subplot(1, 3, 3)
plt.title('Wind 3pm Direction Counts')
sns.countplot(data=df, y='WindDir3pm')
# Out:
# <Axes: title={'center': 'Wind 3pm Direction Counts'}, xlabel='count', ylabel='WindDir3pm'>

# %%
df[['WindGustDir','WindDir9am','WindDir3pm']] = df[['WindGustDir','WindDir9am','WindDir3pm']].fillna(method = 'ffill')
# Out:
# C:\Users\66952\AppData\Local\Temp\ipykernel_16016\2153589757.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['WindGustDir','WindDir9am','WindDir3pm']] = df[['WindGustDir','WindDir9am','WindDir3pm']].fillna(method = 'ffill')
# C:\Users\66952\AppData\Local\Temp\ipykernel_16016\2153589757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['WindGustDir','WindDir9am','WindDir3pm']] = df[['WindGustDir','WindDir9am','WindDir3pm']].fillna(method = 'ffill')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 139451 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           139451 non-null  object
#  1   Location       139451 non-null  object
#  2   MinTemp        139451 non-null  float64
#  3   MaxTemp        139451 non-null  float64
#  4   Rainfall       139451 non-null  float64
#  5   Evaporation    139451 non-null  float64
#  6   Sunshine       139451 non-null  float64
#  7   WindGustDir    139451 non-null  object
#  8   WindGustSpeed  139451 non-null  float64
#  9   WindDir9am     139451 non-null  object
#  10  WindDir3pm     139451 non-null  object
#  11  WindSpeed9am   139451 non-null  float64
#  12  WindSpeed3pm   139451 non-null  float64
#  13  Humidity9am    139451 non-null  float64
#  14  Humidity3pm    139451 non-null  float64
#  15  Pressure9am    139451 non-null  float64
#  16  Pressure3pm    139451 non-null  float64
#  17  Cloud9am       139451 non-null  float64
#  18  Cloud3pm       139451 non-null  float64
#  19  Temp9am        139451 non-null  float64
#  20  Temp3pm        139451 non-null  float64
#  21  RainToday      139451 non-null  object
#  22  RainTomorrow   138087 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
df.loc[df['Rainfall'] > 1, 'RainToday'] = 'Yes'
df.loc[df['Rainfall'] <= 1, 'RainToday'] = 'No'

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['RainTomorrow'] = df['RainToday'].shift(-1)
df = df[df['Date'].diff().dt.days == 1]
# Out:
# C:\Users\66952\AppData\Local\Temp\ipykernel_16016\3200233564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\66952\AppData\Local\Temp\ipykernel_16016\3200233564.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RainTomorrow'] = df['RainToday'].shift(-1)

# %%
df = df.dropna(subset='RainTomorrow')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 135787 entries, 1 to 145458
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           135787 non-null  datetime64[ns]
#  1   Location       135787 non-null  object
#  2   MinTemp        135787 non-null  float64
#  3   MaxTemp        135787 non-null  float64
#  4   Rainfall       135787 non-null  float64
#  5   Evaporation    135787 non-null  float64
#  6   Sunshine       135787 non-null  float64
#  7   WindGustDir    135787 non-null  object
#  8   WindGustSpeed  135787 non-null  float64
#  9   WindDir9am     135787 non-null  object
#  10  WindDir3pm     135787 non-null  object
#  11  WindSpeed9am   135787 non-null  float64
#  12  WindSpeed3pm   135787 non-null  float64
#  13  Humidity9am    135787 non-null  float64
#  14  Humidity3pm    135787 non-null  float64
#  15  Pressure9am    135787 non-null  float64
#  16  Pressure3pm    135787 non-null  float64
#  17  Cloud9am       135787 non-null  float64
#  18  Cloud3pm       135787 non-null  float64
#  19  Temp9am        135787 non-null  float64
#  20  Temp3pm        135787 non-null  float64
#  21  RainToday      135787 non-null  object
#  22  RainTomorrow   135787 non-null  object
# dtypes: datetime64[ns](1), float64(16), object(6)
# memory usage: 24.9+ MB

# %% [markdown]
# # EDA

# %%
plt.figure(figsize = (10,8))
plt.title('Location counts')
sns.countplot(data=df,y='Location')
# Out:
# <Axes: title={'center': 'Location counts'}, xlabel='count', ylabel='Location'>

# %%
plt.title('Number of RainToday')
sns.countplot(data=df,x='RainToday',palette=['mediumturquoise', 'lightcoral'])
# Out:
# C:\Users\66952\AppData\Local\Temp\ipykernel_16016\3339557369.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='RainToday',palette=['mediumturquoise', 'lightcoral'])
# <Axes: title={'center': 'Number of RainToday'}, xlabel='RainToday', ylabel='count'>

# %%
plt.figure(figsize = (10,10))
plt.title('Number of RainToday by each Location')
sns.countplot(data=df,y='Location',hue='RainToday',palette=['mediumturquoise', 'lightcoral'])
# Out:
# <Axes: title={'center': 'Number of RainToday by each Location'}, xlabel='count', ylabel='Location'>

# %%
yearly_rainfall = df.groupby([df['Date'].dt.year])['Rainfall'].sum()
plt.figure(figsize=(10, 6))
plt.plot(yearly_rainfall.index, yearly_rainfall.values, marker='o')
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.title('Yearly Rainfall')
plt.grid(True)
plt.show()

# %%
temp = df
temp['year'] = temp['Date'].dt.year
temp['month'] = temp['Date'].dt.month
temp['day'] = temp['Date'].dt.day
temp
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 1      2008-12-02   Albury      7.4     25.1       0.0          4.8       8.6
# 2      2008-12-03   Albury     12.9     25.7       0.0          4.8       8.6
# 3      2008-12-04   Albury      9.2     28.0       0.0          4.8       8.6
# 4      2008-12-05   Albury     17.5     32.3       1.0          4.8       8.6
# 5      2008-12-06   Albury     14.6     29.7       0.2          4.8       8.6
# ...           ...      ...      ...      ...       ...          ...       ...
# 145454 2017-06-20    Uluru      3.5     21.8       0.0          4.8       8.6
# 145455 2017-06-21    Uluru      2.8     23.4       0.0          4.8       8.6
# 145456 2017-06-22    Uluru      3.6     25.3       0.0          4.8       8.6
# 145457 2017-06-23    Uluru      5.4     26.9       0.0          4.8       8.6
# 145458 2017-06-24    Uluru      7.8     27.0       0.0          4.8       8.6
#
#        WindGustDir  WindGustSpeed WindDir9am  ... Pressure3pm  Cloud9am  \
# 1              WNW           44.0        NNW  ...      1007.8       5.0
# 2              WSW           46.0          W  ...      1008.7       5.0
# 3               NE           24.0         SE  ...      1012.8       5.0
# 4                W           41.0        ENE  ...      1006.0       7.0
# 5              WNW           56.0          W  ...      1005.4       5.0
# ...            ...            ...        ...  ...         ...       ...
# 145454           E           31.0        ESE  ...      1021.2       5.0
# 145455           E           31.0         SE  ...      1020.3       5.0
# 145456         NNW           22.0         SE  ...      1019.1       5.0
# 145457           N           37.0         SE  ...      1016.8       5.0
# 145458          SE           28.0        SSE  ...      1016.5       3.0
#
#         Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 1            5.0     17.2     24.3         No            No  2008     12    2
# 2            2.0     21.0     23.2         No            No  2008     12    3
# 3            5.0     18.1     26.5         No            No  2008     12    4
# 4            8.0     17.8     29.7         No            No  2008     12    5
# 5            5.0     20.6     28.9         No            No  2008     12    6
# ...          ...      ...      ...        ...           ...   ...    ...  ...
# 145454       5.0      9.4     20.9         No            No  2017      6   20
# 145455       5.0     10.1     22.4         No            No  2017      6   21
# 145456       5.0     10.9     24.5         No            No  2017      6   22
# 145457       5.0     12.5     26.1         No            No  2017      6   23
# 145458       2.0     15.1     26.0         No            No  2017      6   24
#
# [135787 rows x 26 columns]

# %%
mintemp = temp.groupby(['year','month'])['MinTemp'].min()
maxtemp = temp.groupby(['year','month'])['MaxTemp'].max()

plt.figure(figsize=(12, 6))
mintemp.plot(marker='o', label='MinTemp')
maxtemp.plot(marker='o', label='MaxTemp')
plt.xlabel('Year, Month')
plt.ylabel('Temperature')
plt.title('MinTemp and MaxTemp over Time')
plt.legend()
plt.show()

# %%
average_rain = temp.groupby(['year','month'])['Rainfall'].mean()

plt.figure(figsize=(12, 6))
average_rain.plot(marker='o')
plt.xlabel('Year-Month')
plt.ylabel('Average Rainfall mm')
plt.title('Average Rainfall over Year-Month')
plt.grid(True)
plt.show()

# %%
wind_speed_by_direction = df.groupby('WindGustDir')['WindGustSpeed'].mean()
wind_speed_by_direction = wind_speed_by_direction.sort_values()

plt.figure(figsize=(12, 6))
plt.bar(wind_speed_by_direction.index, wind_speed_by_direction.values)
plt.xlabel('Wind Direction')
plt.ylabel('Average Wind Gust Speed')
plt.title('Average Wind Gust Speed by Wind Direction')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.735753  0.046310     0.422074  0.049519
# MaxTemp        0.735753  1.000000 -0.173488     0.504733  0.328343
# Rainfall       0.046310 -0.173488  1.000000    -0.117670 -0.177124
# Evaporation    0.422074  0.504733 -0.117670     1.000000  0.341165
# Sunshine       0.049519  0.328343 -0.177124     0.341165  1.000000
# WindGustSpeed  0.201039  0.105060  0.119969     0.170434 -0.001490
# WindSpeed9am   0.184709  0.032752  0.074368     0.150307  0.006001
# WindSpeed3pm   0.185851  0.067204  0.052759     0.126673  0.038846
# Humidity9am   -0.258210 -0.512830  0.272793    -0.417463 -0.322130
# Humidity3pm   -0.015806 -0.513308  0.294447    -0.307323 -0.425527
# Pressure9am   -0.421798 -0.313688 -0.170492    -0.252599  0.020558
# Pressure3pm   -0.430745 -0.401358 -0.104520    -0.275704 -0.026399
# Cloud9am       0.026068 -0.241807  0.186312    -0.180813 -0.500291
# Cloud3pm      -0.015314 -0.225795  0.156403    -0.182445 -0.521663
# Temp9am        0.898718  0.882024 -0.072179     0.492429  0.206441
# Temp3pm        0.701086  0.969929 -0.176551     0.487243  0.344520
# year           0.038739  0.056604 -0.013152     0.042990  0.044520
# month         -0.195988 -0.161778  0.012609    -0.019418  0.011032
# day            0.001746  0.000371  0.003950    -0.007733 -0.000129
#
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp             0.201039      0.184709      0.185851    -0.258210
# MaxTemp             0.105060      0.032752      0.067204    -0.512830
# Rainfall            0.119969      0.074368      0.052759     0.272793
# Evaporation         0.170434      0.150307      0.126673    -0.417463
# Sunshine           -0.001490      0.006001      0.038846    -0.322130
# WindGustSpeed       1.000000      0.528210      0.610853    -0.235664
# WindSpeed9am        0.528210      1.000000      0.456349    -0.286792
# WindSpeed3pm        0.610853      0.456349      1.000000    -0.151712
# Humidity9am        -0.235664     -0.286792     -0.151712     1.000000
# Humidity3pm        -0.055008     -0.050580      0.006367     0.655218
# Pressure9am        -0.386203     -0.201626     -0.256060     0.153477
# Pressure3pm        -0.346857     -0.157455     -0.219404     0.197185
# Cloud9am            0.026062     -0.009170      0.020691     0.347933
# Cloud3pm            0.051665      0.009471     -0.002254     0.271754
# Temp9am             0.180118      0.143164      0.178431    -0.491692
# Temp3pm             0.073834      0.022464      0.047307    -0.504522
# year               -0.029800     -0.018432     -0.032021     0.011674
# month               0.052054      0.054321      0.056462    -0.085415
# day                -0.011892     -0.009072     -0.010486     0.015480
#
#                Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# MinTemp          -0.015806    -0.421798    -0.430745  0.026068 -0.015314
# MaxTemp          -0.513308    -0.313688    -0.401358 -0.241807 -0.225795
# Rainfall          0.294447    -0.170492    -0.104520  0.186312  0.156403
# Evaporation      -0.307323    -0.252599    -0.275704 -0.180813 -0.182445
# Sunshine         -0.425527     0.020558    -0.026399 -0.500291 -0.521663
# WindGustSpeed    -0.055008    -0.386203    -0.346857  0.026062  0.051665
# WindSpeed9am     -0.050580    -0.201626    -0.157455 -0.009170  0.009471
# WindSpeed3pm      0.006367    -0.256060    -0.219404  0.020691 -0.002254
# Humidity9am       0.655218     0.153477     0.197185  0.347933  0.271754
# Humidity3pm       1.000000    -0.008304     0.066795  0.391097  0.396318
# Pressure9am      -0.008304     1.000000     0.959866 -0.083814 -0.099851
# Pressure3pm       0.066795     0.959866     1.000000 -0.029898 -0.051696
# Cloud9am          0.391097    -0.083814    -0.029898  1.000000  0.562176
# Cloud3pm          0.396318    -0.099851    -0.051696  0.562176  1.000000
# Temp9am          -0.236051    -0.398774    -0.442163 -0.135915 -0.122895
# Temp3pm          -0.570051    -0.270269    -0.364837 -0.247124 -0.260625
# year             -0.007695     0.029928     0.025181  0.062752  0.049006
# month            -0.008444     0.028785     0.019494 -0.002653  0.002630
# day               0.013707    -0.021878    -0.022194  0.005369 -0.000653
#
#                 Temp9am   Temp3pm      year     month       day
# MinTemp        0.898718  0.701086  0.038739 -0.195988  0.001746
# MaxTemp        0.882024  0.969929  0.056604 -0.161778  0.000371
# Rainfall      -0.072179 -0.176551 -0.013152  0.012609  0.003950
# Evaporation    0.492429  0.487243  0.042990 -0.019418 -0.007733
# Sunshine       0.206441  0.344520  0.044520  0.011032 -0.000129
# WindGustSpeed  0.180118  0.073834 -0.029800  0.052054 -0.011892
# WindSpeed9am   0.143164  0.022464 -0.018432  0.054321 -0.009072
# WindSpeed3pm   0.178431  0.047307 -0.032021  0.056462 -0.010486
# Humidity9am   -0.491692 -0.504522  0.011674 -0.085415  0.015480
# Humidity3pm   -0.236051 -0.570051 -0.007695 -0.008444  0.013707
# Pressure9am   -0.398774 -0.270269  0.029928  0.028785 -0.021878
# Pressure3pm   -0.442163 -0.364837  0.025181  0.019494 -0.022194
# Cloud9am      -0.135915 -0.247124  0.062752 -0.002653  0.005369
# Cloud3pm      -0.122895 -0.260625  0.049006  0.002630 -0.000653
# Temp9am        1.000000  0.847667  0.041318 -0.129085 -0.000190
# Temp3pm        0.847667  1.000000  0.045387 -0.171651 -0.000729
# year           0.041318  0.045387  1.000000 -0.111352 -0.005942
# month         -0.129085 -0.171651 -0.111352  1.000000  0.006872
# day           -0.000190 -0.000729 -0.005942  0.006872  1.000000

# %%
plt.figure(figsize = (8,6))
sns.heatmap(data=df.corr(numeric_only=True),cmap='RdBu',vmin=-1,vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# # Select relevant columns

# %% [markdown]
# 1. นำ column 'Date' ไปเป็น index
# 2. drop column 'RainToday' เพราะสามารถ derive มาจาก column 'Rainfall'
# 3. drop column 'Location' เพราะมีจำนวน category เยอะทำให้ model ทำงานได้ไม่ดี

# %%
df = df.drop(columns = ['RainToday','Location', 'Date'])

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1      7.4     25.1       0.0          4.8       8.6         WNW
# 2     12.9     25.7       0.0          4.8       8.6         WSW
# 3      9.2     28.0       0.0          4.8       8.6          NE
# 4     17.5     32.3       1.0          4.8       8.6           W
# 5     14.6     29.7       0.2          4.8       8.6         WNW
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Pressure9am  \
# 1           44.0        NNW        WSW           4.0  ...       1010.6
# 2           46.0          W        WSW          19.0  ...       1007.6
# 3           24.0         SE          E          11.0  ...       1017.6
# 4           41.0        ENE         NW           7.0  ...       1010.8
# 5           56.0          W          W          19.0  ...       1009.2
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainTomorrow  year  \
# 1       1007.8       5.0       5.0     17.2     24.3            No  2008
# 2       1008.7       5.0       2.0     21.0     23.2            No  2008
# 3       1012.8       5.0       5.0     18.1     26.5            No  2008
# 4       1006.0       7.0       8.0     17.8     29.7            No  2008
# 5       1005.4       5.0       5.0     20.6     28.9            No  2008
#
#    month day
# 1     12   2
# 2     12   3
# 3     12   4
# 4     12   5
# 5     12   6
#
# [5 rows x 23 columns]

# %% [markdown]
# # Data preparation

# %%
df_num = df.select_dtypes('number')
df_object = df.select_dtypes('object')
df_object1 = pd.get_dummies(df_object, drop_first=True)
df_prep = pd.concat([df_num, df_object1], axis=1)

# %%
df_prep.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'year', 'month', 'day', 'WindGustDir_ENE',
#        'WindGustDir_ESE', 'WindGustDir_N', 'WindGustDir_NE', 'WindGustDir_NNE',
#        'WindGustDir_NNW', 'WindGustDir_NW', 'WindGustDir_S', 'WindGustDir_SE',
#        'WindGustDir_SSE', 'WindGustDir_SSW', 'WindGustDir_SW', 'WindGustDir_W',
#        'WindGustDir_WNW', 'WindGustDir_WSW', 'WindDir9am_ENE',
#        'WindDir9am_ESE', 'WindDir9am_N', 'WindDir9am_NE', 'WindDir9am_NNE',
#        'WindDir9am_NNW', 'WindDir9am_NW', 'WindDir9am_S', 'WindDir9am_SE',
#        'WindDir9am_SSE', 'WindDir9am_SSW', 'WindDir9am_SW', 'WindDir9am_W',
#        'WindDir9am_WNW', 'WindDir9am_WSW', 'WindDir3pm_ENE', 'WindDir3pm_ESE',
#        'WindDir3pm_N', 'WindDir3pm_NE', 'WindDir3pm_NNE', 'WindDir3pm_NNW',
#        'WindDir3pm_NW', 'WindDir3pm_S', 'WindDir3pm_SE', 'WindDir3pm_SSE',
#        'WindDir3pm_SSW', 'WindDir3pm_SW', 'WindDir3pm_W', 'WindDir3pm_WNW',
#        'WindDir3pm_WSW', 'RainTomorrow_Yes'],
#       dtype='object')

# %%
df_prep
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 1           7.4     25.1       0.0          4.8       8.6           44.0
# 2          12.9     25.7       0.0          4.8       8.6           46.0
# 3           9.2     28.0       0.0          4.8       8.6           24.0
# 4          17.5     32.3       1.0          4.8       8.6           41.0
# 5          14.6     29.7       0.2          4.8       8.6           56.0
# ...         ...      ...       ...          ...       ...            ...
# 145454      3.5     21.8       0.0          4.8       8.6           31.0
# 145455      2.8     23.4       0.0          4.8       8.6           31.0
# 145456      3.6     25.3       0.0          4.8       8.6           22.0
# 145457      5.4     26.9       0.0          4.8       8.6           37.0
# 145458      7.8     27.0       0.0          4.8       8.6           28.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 1                4.0          22.0         44.0         25.0  ...
# 2               19.0          26.0         38.0         30.0  ...
# 3               11.0           9.0         45.0         16.0  ...
# 4                7.0          20.0         82.0         33.0  ...
# 5               19.0          24.0         55.0         23.0  ...
# ...              ...           ...          ...          ...  ...
# 145454          15.0          13.0         59.0         27.0  ...
# 145455          13.0          11.0         51.0         24.0  ...
# 145456          13.0           9.0         56.0         21.0  ...
# 145457           9.0           9.0         53.0         24.0  ...
# 145458          13.0           7.0         51.0         24.0  ...
#
#         WindDir3pm_NW  WindDir3pm_S  WindDir3pm_SE  WindDir3pm_SSE  \
# 1               False         False          False           False
# 2               False         False          False           False
# 3               False         False          False           False
# 4                True         False          False           False
# 5               False         False          False           False
# ...               ...           ...            ...             ...
# 145454          False         False          False           False
# 145455          False         False          False           False
# 145456          False         False          False           False
# 145457          False         False          False           False
# 145458          False         False          False           False
#
#         WindDir3pm_SSW  WindDir3pm_SW  WindDir3pm_W  WindDir3pm_WNW  \
# 1                False          False         False           False
# 2                False          False         False           False
# 3                False          False         False           False
# 4                False          False         False           False
# 5                False          False          True           False
# ...                ...            ...           ...             ...
# 145454           False          False         False           False
# 145455           False          False         False           False
# 145456           False          False         False           False
# 145457           False          False         False            True
# 145458           False          False         False           False
#
#         WindDir3pm_WSW  RainTomorrow_Yes
# 1                 True             False
# 2                 True             False
# 3                False             False
# 4                False             False
# 5                False             False
# ...                ...               ...
# 145454           False             False
# 145455           False             False
# 145456           False             False
# 145457           False             False
# 145458           False             False
#
# [135787 rows x 65 columns]

# %% [markdown]
# # Sample data

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(df_prep, train_size=0.7)

# %%
df_train.shape
# Out:
# (95050, 65)

# %%
df_test.shape
# Out:
# (40737, 65)

# %%
x_train = df_train.drop(columns = 'RainTomorrow_Yes')
y_train = df_train['RainTomorrow_Yes']

# %%
x_test = df_test.drop(columns = 'RainTomorrow_Yes')
y_test = df_test['RainTomorrow_Yes']

# %% [markdown]
# # Train random forest classifier model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
rfmodel = RandomForestClassifier(n_estimators=1000, class_weight='balanced', n_jobs=-1, min_samples_leaf=5, bootstrap=True, min_samples_split= 5, max_samples=0.5, max_depth=30)
rfmodel.fit(x_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=30, max_samples=0.5,
#                        min_samples_leaf=5, min_samples_split=5,
#                        n_estimators=1000, n_jobs=-1)

# %%
rfmodel.feature_importances_
# Out:
# array([0.04052993, 0.04024932, 0.06939931, 0.01944423, 0.07506788,
#        0.04725716, 0.02197003, 0.02390612, 0.05799242, 0.18658316,
#        0.05995462, 0.06801799, 0.02696707, 0.05090448, 0.03533533,
#        0.04699984, 0.01755747, 0.02081658, 0.02508789, 0.00096772,
#        0.0008607 , 0.00175641, 0.00150383, 0.00127462, 0.00145583,
#        0.00165881, 0.00131779, 0.00115173, 0.00122347, 0.0011391 ,
#        0.00116622, 0.00251814, 0.00122174, 0.00113615, 0.00092843,
#        0.00097649, 0.00355773, 0.00136631, 0.00228974, 0.00137969,
#        0.00158331, 0.00145217, 0.00140796, 0.00146664, 0.00130135,
#        0.00128401, 0.0013777 , 0.00114548, 0.00114966, 0.00090557,
#        0.00103246, 0.0027244 , 0.00186265, 0.00140913, 0.00190125,
#        0.00184499, 0.00139447, 0.00159744, 0.0014068 , 0.0011171 ,
#        0.001377  , 0.00145827, 0.00165228, 0.00125645])

# %%
pd.DataFrame(dict(Feature=df_train.columns[:-1],
                  Value=rfmodel.feature_importances_))\
  .sort_values(by='Value', ascending=False).head(10)
# Out:
#           Feature     Value
# 9     Humidity3pm  0.186583
# 4        Sunshine  0.075068
# 2        Rainfall  0.069399
# 11    Pressure3pm  0.068018
# 10    Pressure9am  0.059955
# 8     Humidity9am  0.057992
# 13       Cloud3pm  0.050904
# 5   WindGustSpeed  0.047257
# 15        Temp3pm  0.047000
# 0         MinTemp  0.040530

# %% [markdown]
# # Prediction

# %%
y_pred = rfmodel.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False,  True])

# %% [markdown]
# # Classification report

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90     32435
#         True       0.61      0.62      0.61      8302
#
#     accuracy                           0.84     40737
#    macro avg       0.75      0.76      0.76     40737
# weighted avg       0.84      0.84      0.84     40737

# %%
pd.crosstab(index=y_pred,columns=df_test['RainTomorrow_Yes'])
# Out:
# RainTomorrow_Yes  False  True
# row_0
# False             29059   3129
# True               3376   5173
